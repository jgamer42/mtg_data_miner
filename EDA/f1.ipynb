# %% [markdown]
# <a href="https://colab.research.google.com/github/jgamer42/mtg_data_miner/blob/master/f1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
standard_dataset = pd.read_csv("standard.csv",index_col='name',parse_dates=True)
pauper_dataset = pd.read_csv("pauper.csv",index_col='name',parse_dates=True)
pioneer_dataset = pd.read_csv("pioneer.csv",index_col='name',parse_dates=True)
modern_dataset = pd.read_csv("modern.csv",index_col='name',parse_dates=True)

# %%
standard_dataset.columns
# Out:
# Index(['Unnamed: 0', 'format', 'deck_percentage', 'count', 'strategy', 'date',
#        'rare', 'comm', 'unc', 'mythic', 'wave_0', 'wave_1', 'wave_2', 'wave_3',
#        'wave_4', 'wave_5', 'wave_6', 'wave_7', 'domain_collection',
#        'domain_in_Spells', 'Spells_wave_0', 'Spells_wave_1', 'Spells_wave_2',
#        'Spells_wave_3', 'Spells_wave_4', 'Spells_wave_5', 'Spells_wave_6',
#        'Spells_wave_7', 'Spells_rare', 'Spells_comm', 'Spells_unc',
#        'Spells_mythic', 'domain_in_Artifacts', 'Artifacts_wave_0',
#        'Artifacts_wave_1', 'Artifacts_wave_2', 'Artifacts_wave_3',
#        'Artifacts_wave_4', 'Artifacts_wave_5', 'Artifacts_wave_6',
#        'Artifacts_wave_7', 'Artifacts_rare', 'Artifacts_comm', 'Artifacts_unc',
#        'Artifacts_mythic', 'domain_in_Lands', 'Lands_wave_0', 'Lands_wave_1',
#        'Lands_wave_2', 'Lands_wave_3', 'Lands_wave_4', 'Lands_wave_5',
#        'Lands_wave_6', 'Lands_wave_7', 'Lands_rare', 'Lands_comm', 'Lands_unc',
# ...

# %%
standard_dataset.head()
# Out:
#                   Unnamed: 0    format deck_percentage  count  strategy  \
# name
# Mono-White Aggro           0  standard            2.5%    2.0       NaN
# Izzet Delver               1  standard             NaN    NaN       NaN
# Jeskai Storm               2  standard            3.7%    3.0       NaN
# Izzet Control              3  standard            2.5%    2.0       NaN
# Mardu Midrange             4  standard            2.5%    2.0       NaN
#
#                         date  rare  comm  unc  mythic  ...  \
# name                                                   ...
# Mono-White Aggro  2022-05-29    32     0    4       8  ...
# Izzet Delver      2022-05-29    12    18   18       2  ...
# Jeskai Storm      2022-05-29    20     9   16       7  ...
# Izzet Control     2022-05-29    19    13   15       7  ...
# Mardu Midrange    2022-05-29    45     2    0      13  ...
#
#                   Planeswalkers_wave_2  Planeswalkers_wave_3  \
# name
# ...

# %%
standard_mana_waves = standard_dataset[["wave_0","wave_1","wave_2","wave_3","wave_4","wave_5","wave_6","wave_7"]]
modern_mana_waves = modern_dataset[["wave_0","wave_1","wave_2","wave_3","wave_4","wave_5","wave_6","wave_7"]]
pauper_mana_waves = pauper_dataset[["wave_0","wave_1","wave_2","wave_3","wave_4","wave_5","wave_6","wave_7"]]
pioneer_mana_waves = pioneer_dataset[["wave_0","wave_1","wave_2","wave_3","wave_4","wave_5","wave_6","wave_7"]]

# %%
standard_mana_waves.head().plot(kind="bar")

# %%
modern_mana_waves.head().plot(kind="bar")

# %%
pauper_mana_waves.head().plot(kind="bar")

# %%
pioneer_mana_waves.head().plot(kind="bar")

# %%
domain_collections_standard = standard_dataset["domain_collection"]
aux = {}
for collection in domain_collections_standard:
  if collection in aux:
    aux[collection][0] += 1
  else:
    aux[collection] = [1]
a = pd.DataFrame(aux)
a.plot(kind="bar")

# %%
domain_collections_modern = modern_dataset["domain_collection"]
aux = {}
for collection in domain_collections_modern:
  if collection in aux:
    aux[collection][0] += 1
  else:
    aux[collection] = [1]
a = pd.DataFrame(aux)
a.plot(kind="bar")

# %%
domain_collections_pauper = pauper_dataset["domain_collection"]
aux = {}
for collection in domain_collections_pauper:
  if collection in aux:
    aux[collection][0] += 1
  else:
    aux[collection] = [1]
a = pd.DataFrame(aux)
a.plot(kind="bar")

# %%
domain_collections_pioneer = pioneer_dataset["domain_collection"]
aux = {}
for collection in domain_collections_pioneer:
  if collection in aux:
    aux[collection][0] += 1
  else:
    aux[collection] = [1]
a = pd.DataFrame(aux)
a.plot(kind="bar")

# %%
standard_rarity = standard_dataset[['rare', 'comm', 'unc', 'mythic']]
aux = {
    "rare":[sum(standard_rarity["rare"])],
    "comm":[sum(standard_rarity["comm"])],
    "unc":[sum(standard_rarity["unc"])],
    "mythic":[sum(standard_rarity["mythic"])],
}
aux
a = pd.DataFrame(aux)
a.plot(kind="bar")

# %%
modern_rarity = modern_dataset[['rare', 'comm', 'unc', 'mythic']]
aux = {
    "rare":[sum(modern_rarity["rare"])],
    "comm":[sum(modern_rarity["comm"])],
    "unc":[sum(modern_rarity["unc"])],
    "mythic":[sum(modern_rarity["mythic"])],
}
aux
a = pd.DataFrame(aux)
a.plot(kind="bar")

# %%
pioneer_rarity = pioneer_dataset[['rare', 'comm', 'unc', 'mythic']]
aux = {
    "rare":[sum(pioneer_rarity["rare"])],
    "comm":[sum(pioneer_rarity["comm"])],
    "unc":[sum(pioneer_rarity["unc"])],
    "mythic":[sum(pioneer_rarity["mythic"])],
}
aux
a = pd.DataFrame(aux)
a.plot(kind="bar")

# %%
pauper_rarity = pauper_dataset[['rare', 'comm', 'unc', 'mythic']]
aux = {
    "rare":[sum(pauper_rarity["rare"])],
    "comm":[sum(pauper_rarity["comm"])],
    "unc":[sum(pauper_rarity["unc"])],
    "mythic":[sum(pauper_rarity["mythic"])],
}
aux
a = pd.DataFrame(aux)
a.plot(kind="bar")
